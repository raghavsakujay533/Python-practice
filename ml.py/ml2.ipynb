# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as pl

# %%
df=pd.read_csv("linedata1.csv")
df
# Out:
#    salary  expenses
# 0   40000     30000
# 1   35000     29000
# 2   67000     50000
# 3   45000     32000
# 4   45600      8000

# %%
x=df[["salary"]]
y=df.expenses

# %%
pl.plot(x,y,color="red",marker="+")
pl.xlabel("--x--axis")
pl.ylabel("--y--axis")
pl.title("yeh ek plot hai")
# Out:
# Text(0.5, 1.0, 'yeh ek plot hai')

# %%
model=LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[40000]])
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([25019.45775232])

# %%
m=model.coef_
print(m)
# Out:
# [0.733212]

# %%
b=model.intercept_
print(b)
# Out:
# -4309.0222947836155

# %%
y=(m*40000)+b

# %%
print(y)
# Out:
# [25019.45775232]

# %%
pl.ylabel(y)
pl.xlabel(x)
x
y
pl.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df=pd.read_csv("area.csv")
df
df.head()
# Out:
#    area
# 0    40
# 1    70
# 2    90
# 3    45
# 4    34
